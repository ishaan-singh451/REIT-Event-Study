# %% [markdown]
# # Studying the Impact of COVID-19 on Australian Real Estate Investment Trusts

# %%
import pandas as pd

# %%
SCG = pd.read_csv("SCG.csv")
SCP = pd.read_csv("SCP.csv")
VCX = pd.read_csv("VCX.csv")
ASX = pd.read_csv("ASX.csv")
ALU = pd.read_csv("ALU.csv")
TNE = pd.read_csv("TNE.csv")
XRO = pd.read_csv("XRO.csv")

stocks = [SCG, SCP, VCX, ALU, TNE, XRO]

# %%
for stock in stocks:
    stock['Return'] = (stock['Close'] - stock['Close'].shift(1))/stock['Close'].shift(1)
    stock['Date'] = stock['Date'].astype(str)
    stock['Date'] = pd.to_datetime(stock['Date'], format = '%d/%m/%y')
ASX['Date'] = pd.to_datetime(ASX['Date'], format = '%m/%d/%y')
ASX['Return'] = (ASX[' Close'] - ASX[' Close'].shift(1))/ASX[' Close'].shift(1)
ASX = ASX.drop(labels = 0, axis = 0)
SCG = SCG.drop(labels = 0, axis = 0)
SCP = SCP.drop(labels = 0, axis = 0)
VCX = VCX.drop(labels = 0, axis = 0)
ALU = ALU.drop(labels = 0, axis = 0)
TNE = TNE.drop(labels = 0, axis = 0)
XRO = XRO.drop(labels = 0, axis = 0)

# %%
SCG = SCG[SCG['Date'] >= "2019-08-14"]
SCG_normal = SCG[SCG['Date'] < "2020-03-01"]
SCG_one = SCG[(SCG['Date'] >= "2020-03-01") & (SCG['Date'] < "2020-03-18")]
SCG_two = SCG[(SCG['Date'] >= "2020-03-18") & (SCG['Date'] < "2020-03-29")]
SCG_three = SCG[(SCG['Date'] >= "2020-03-29") & (SCG['Date'] < "2020-04-13")]
SCG_four = SCG[(SCG['Date'] >= "2020-04-13") & (SCG['Date'] < "2020-06-14")]

SCP = SCP[SCP['Date'] >= "2019-08-14"]
SCP_normal = SCP[SCP['Date'] < "2020-03-01"]
SCP_one = SCP[(SCP['Date'] >= "2020-03-01") & (SCP['Date'] < "2020-03-18")]
SCP_two = SCP[(SCP['Date'] >= "2020-03-18") & (SCP['Date'] < "2020-03-29")]
SCP_three = SCP[(SCP['Date'] >= "2020-03-29") & (SCP['Date'] < "2020-04-13")]
SCP_four = SCP[(SCP['Date'] >= "2020-04-13") & (SCP['Date'] < "2020-06-14")]

VCX = VCX[VCX['Date'] >= "2019-08-14"]
VCX_normal = VCX[VCX['Date'] < "2020-03-01"]
VCX_one = VCX[(VCX['Date'] >= "2020-03-01") & (VCX['Date'] < "2020-03-18")]
VCX_two = VCX[(VCX['Date'] >= "2020-03-18") & (VCX['Date'] < "2020-03-29")]
VCX_three = VCX[(VCX['Date'] >= "2020-03-29") & (VCX['Date'] < "2020-04-13")]
VCX_four = VCX[(VCX['Date'] >= "2020-04-13") & (VCX['Date'] < "2020-06-14")]

ASX = ASX[ASX['Date'] >= "2019-08-14"]
ASX_normal = ASX[ASX['Date'] < "2020-03-01"]
ASX_one = ASX[(ASX['Date'] >= "2020-03-01") & (ASX['Date'] < "2020-03-18")]
ASX_two = ASX[(ASX['Date'] >= "2020-03-18") & (ASX['Date'] < "2020-03-29")]
ASX_three = ASX[(ASX['Date'] >= "2020-03-29") & (ASX['Date'] < "2020-04-13")]
ASX_four = ASX[(ASX['Date'] >= "2020-04-13") & (ASX['Date'] < "2020-06-14")]

ASX = ASX[ASX['Date'] >= "2019-08-14"]
ASX_normal = ASX[ASX['Date'] < "2020-03-01"]
ASX_one = ASX[(ASX['Date'] >= "2020-03-01") & (ASX['Date'] < "2020-03-18")]
ASX_two = ASX[(ASX['Date'] >= "2020-03-18") & (ASX['Date'] < "2020-03-29")]
ASX_three = ASX[(ASX['Date'] >= "2020-03-29") & (ASX['Date'] < "2020-04-13")]
ASX_four = ASX[(ASX['Date'] >= "2020-04-13") & (ASX['Date'] < "2020-06-14")]

ALU = ALU[ALU['Date'] >= "2019-08-14"]
ALU_normal = ALU[ALU['Date'] < "2020-03-01"]
ALU_one = ALU[(ALU['Date'] >= "2020-03-01") & (ALU['Date'] < "2020-03-18")]
ALU_two = ALU[(ALU['Date'] >= "2020-03-18") & (ALU['Date'] < "2020-03-29")]
ALU_three = ALU[(ALU['Date'] >= "2020-03-29") & (ALU['Date'] < "2020-04-13")]
ALU_four = ALU[(ALU['Date'] >= "2020-04-13") & (ALU['Date'] < "2020-06-14")]

TNE = TNE[TNE['Date'] >= "2019-08-14"]
TNE_normal = TNE[TNE['Date'] < "2020-03-01"]
TNE_one = TNE[(TNE['Date'] >= "2020-03-01") & (TNE['Date'] < "2020-03-18")]
TNE_two = TNE[(TNE['Date'] >= "2020-03-18") & (TNE['Date'] < "2020-03-29")]
TNE_three = TNE[(TNE['Date'] >= "2020-03-29") & (TNE['Date'] < "2020-04-13")]
TNE_four = TNE[(TNE['Date'] >= "2020-04-13") & (TNE['Date'] < "2020-06-14")]
# Out:
#     ASX Code   Company Name       Date  Open  High    Low  Close  \
# 1        SCG  Scentre Group 2019-08-14  3.92  3.93  3.830   3.87
# 2        SCG  Scentre Group 2019-08-15  3.83  3.84  3.770   3.80
# 3        SCG  Scentre Group 2019-08-16  3.81  3.83  3.770   3.79
# 4        SCG  Scentre Group 2019-08-19  3.88  3.89  3.830   3.83
# 5        SCG  Scentre Group 2019-08-20  3.85  3.90  3.845   3.90
# ..       ...            ...        ...   ...   ...    ...    ...
# 207      SCG  Scentre Group 2020-06-05  2.48  2.53  2.450   2.51
# 208      SCG  Scentre Group 2020-06-09  2.62  2.77  2.620   2.73
# 209      SCG  Scentre Group 2020-06-10  2.68  2.68  2.600   2.61
# 210      SCG  Scentre Group 2020-06-11  2.50  2.53  2.400   2.40
# 211      SCG  Scentre Group 2020-06-12  2.30  2.34  2.200   2.29
#
#             Volume Market Capitalisation($m)   Shares on Issue    Return
# 1    10,962,434.00                 20,576.78  5,316,997,206.00 -0.027638
# ...
