# %% [markdown]
# # Studying the Impact of COVID-19 on Australian Real Estate Investment Trusts

# %%
import pandas as pd
SCG = pd.read_csv("SCG.csv")
SCP = pd.read_csv("SCP.csv")
VCX = pd.read_csv("VCX.csv")
ASX = pd.read_csv("ASX.csv")
ALU = pd.read_csv("ALU.csv")
TNE = pd.read_csv("TNE.csv")
XRO = pd.read_csv("XRO.csv")

stocks = [SCG, SCP, VCX, ALU, TNE, XRO]

# %%
for stock in stocks:
    stock['Return'] = (stock['Close'] - stock['Close'].shift(1))/stock['Close'].shift(1)
    # stock['Date'] = pd.to_datetime(stock['Return'], infer_datetime_format = True)
ASX['Return'] = (ASX[' Close'] - ASX[' Close'].shift(1))/ASX[' Close'].shift(1)

# %%
# Out:
#     ASX Code   Company Name     Date  Open  High    Low  Close         Volume  \
# 0        SCG  Scentre Group  13/8/19  4.00  4.03  3.970   3.98   9,364,441.00
# 1        SCG  Scentre Group  14/8/19  3.92  3.93  3.830   3.87  10,962,434.00
# 2        SCG  Scentre Group  15/8/19  3.83  3.84  3.770   3.80  11,626,770.00
# 3        SCG  Scentre Group  16/8/19  3.81  3.83  3.770   3.79  12,696,578.00
# 4        SCG  Scentre Group  19/8/19  3.88  3.89  3.830   3.83   9,942,337.00
# ..       ...            ...      ...   ...   ...    ...    ...            ...
# 206      SCG  Scentre Group   4/6/20  2.49  2.53  2.445   2.48  30,520,601.00
# 207      SCG  Scentre Group   5/6/20  2.48  2.53  2.450   2.51  23,442,662.00
# 208      SCG  Scentre Group   9/6/20  2.62  2.77  2.620   2.73  40,945,749.00
# 210      SCG  Scentre Group  11/6/20  2.50  2.53  2.400   2.40  47,569,773.00
# 211      SCG  Scentre Group  12/6/20  2.30  2.34  2.200   2.29  49,052,296.00
#
# ...
